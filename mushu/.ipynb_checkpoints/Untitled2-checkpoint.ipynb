# %%
import asyncio
import threading

# so you can use a spearate thread to wait/check for incoming event/thing, to then shut down the main event loop.
# I guess this is poison-pill technique.
def stop_loop():
        input('Press <enter> to stop')
        loop.call_soon_threadsafe(loop.stop)

loop = asyncio.get_event_loop()
threading.Thread(target=stop_loop).start()
loop.run_forever()
loop.close()  # optional
# Out:
# Press <enter> to stop

# %%
ls
# Out:
#  async.py           prepare_github_pages.sh*        tcp.py
#  doc/               __pycache__/                    test/
#  generate_doc.sh*   README.md                       TODO
#  libmushu/          Remote_Control_Recorder.ipynb   tools/
#  LICENSE            requirements.txt                Untitled1.ipynb
#  mushu.py*          setup.py*                       Untitled2.ipynb
#  my_server.py      'Short Amp Test.ipynb'           Untitled.ipynb
#  play/              StartingRecorder.ipynb          usb-dumps/
